# %% [markdown]
# <a href="https://colab.research.google.com/github/Joel-k-sony/AI-ML-internship/blob/main/day_2_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **strings**

# %%
print("hello")
print('hai')
# Out:
# hello
# hai

# %% [markdown]
# **\n**

# %%
print("hello \nworld ")
print("hai")
# Out:
# hello
# world
# hai

# %% [markdown]
# **len()**

# %%
a="cristiano ronaldo"
print(len(a))
# Out:
# 17

# %%
print(a[0])
print(a[3])
print(a[-1])
print(a[-4])
# Out:
# c
# s
# o
# a

# %% [markdown]
# **slicing**

# %%
print(a[:10])
print(a[10:])
# Out:
# cristiano
# ronaldo

# %%
print(a[1:4])
print(a[-5:])
print(a[-5:-3])
print(a[:])
# Out:
# ris
# naldo
# na
# cristiano ronaldo

# %% [markdown]
# **step size**

# %%
print(a[::1])
print(a[::2])
print(a[::3])
# Out:
# cristiano ronaldo
# citaornlo
# csa nd

# %%
print(a[4::1])
print(a[4::2])
# Out:
# tiano ronaldo
# taornlo

# %%
print(a[::-1])
print(a[::-2])
# Out:
# odlanor onaitsirc
# olnroatic

# %% [markdown]
# ### **adding- integers ,letters**

# %%
x=1
y=2
print(x+y)

x="1"
y="2"
print(x+y)
# Out:
# 3
# 12

# %%
b='hello'
c='my'
d='friends'
print(b+c+d)
# Out:
# hellomyfriends

# %% [markdown]
# ### **functions and methods**

# %%
name='cristiano ronaldo'
print(name)
# Out:
# cristiano ronaldo

# %%
print(name.lower())#lowercase
print(name.upper())#uppercase
# Out:
# cristiano ronaldo
# CRISTIANO RONALDO

# %%
#count
n='cristiano ronaldo'
print(n.count('i'))
print(n.count('o'))
# Out:
# 2
# 3

# %%
#find
print(n.find('c'))
print(n.find('a'))
# Out:
# 0
# 6

# %%
#len
print(len(n))
# Out:
# 17

# %%
#replace
s= "joel k sony"
print(s.replace('','_'))
# Out:
# _j_o_e_l_ _k_ _s_o_n_y_

# %%
#print(f'....')
first_name= "issac"
last_name= "newton"
print(f'the person {first_name} {last_name} was a well known scientist')
# Out:
# the person issac newton was a well known scientist

# %% [markdown]
# # ***day 2 task***

# %% [markdown]
# **Create a program that stores your name in a string and prints it in uppercase.**

# %%
name="joel k sony"
print(name.upper())
# Out:
# JOEL K SONY

# %% [markdown]
# **Write a program to store a sentence and print only the first character and last character.**

# %%
sentence="cristiano ronaldo"
print(sentence[0])
print(sentence[-1])
# Out:
# c
# o

# %% [markdown]
# **Create a string "Python Programming" and print the total number of characters using a string method**

# %%
p="Python Programming"
print(len(p))
# Out:
# 18

# %% [markdown]
# **Store "hello world" in a variable and print it with the first letter of each word capitalized.**

# %%
variable="hello world"
print(variable.title())
# Out:
# Hello World

# %% [markdown]
# **Write a program to replace all spaces in a sentence with -**

# %%
space="greatest of all time"
print(space.replace(' ','-'))
# Out:
# greatest-of-all-time

# %% [markdown]
# **Create a string "banana" and print how many times the letter "a" appears.**

# %%
string="banana"
print(string.count('a'))
# Out:
# 3

# %% [markdown]
# **Store your favorite movie name in a string and print it in lowercase.**

# %%
movie="CID MOOSA"
print(movie.lower())
# Out:
# cid moosa

# %% [markdown]
# **Write a program to check whether the word "Python" exists inside the sentence "I am learning Python today".**

# %%
exists="I am learning Python today"
print(exists.find("Python"))
print("Python" in exists)
# Out:
# 14
# True

# %% [markdown]
# **Create a string with extra spaces at the beginning and end, then remove the spaces and print the result.**

# %%
spaced_string = "   greatest of all time  "
print(f"Original: '{spaced_string}'")
print(f"Stripped: '{spaced_string.strip()}'")
# Out:
# Original: '   greatest of all time  '
# Stripped: 'greatest of all time'

# %% [markdown]
# **Store "apple,mango,orange" in a string and split it into separate fruits using a string method.**

# %%
fruits= "apple,mango,orange"
fruit_list = fruits.split(',')
print(fruit_list)
# Out:
# ['apple', 'mango', 'orange']
