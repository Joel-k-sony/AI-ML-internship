# %% [markdown]
# <a href="https://colab.research.google.com/github/Joel-k-sony/AI-ML-internship/blob/main/day_1_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=6
print(x)
# Out:
# 6

# %% [markdown]
# ## **relational** **operation**

# %%
x=5
y=10
print(x>y)
print(y>x)
print(x!=y)
print(y==x)
# Out:
# False
# True
# True
# False

# %% [markdown]
# ## **type** **casting**

# %%
x=7
print(type(x))
# Out:
# <class 'int'>

# %%
x='joel'
print(type(x))
# Out:
# <class 'str'>

# %%
x=input()
print(x)
print(type(x))
# Out:
# 7
# 7
# <class 'str'>

# %% [markdown]
# ## **arithematic** **operation**

# %%
a=5
b=10
print(a+b)
print(a-b)
print(a*b)
print(a/b)
# Out:
# 15
# -5
# 50
# 0.5

# %%
a='cristiano'
b='ronaldo'
print(a+b)
# Out:
# cristianoronaldo

# %% [markdown]
# ## **data types**

# %%
print(type(0.7))
print(type(True))
print(type(7))
print(type("ronaldo"))
# Out:
# <class 'float'>
# <class 'bool'>
# <class 'int'>
# <class 'str'>
